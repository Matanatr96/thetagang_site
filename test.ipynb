# %%
import sqlalchemy
import django
from django.conf import settings

# %%
settings
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# File c:\Users\anush\Documents\My Life Documents\Fun\Coding\thetagang_site\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3375, in InteractiveShell.transform_cell(self, raw_cell)
#    3370 if len(cell.splitlines()) == 1:
#    3371     # Dynamic transformations - only applied for single line commands
#    3372     with self.builtin_trap:
#    3373         # use prefilter_lines to handle trailing newlines
#    3374         # restore trailing newline for ast.parse
# -> 3375         cell = self.prefilter_manager.prefilter_lines(cell) + '\n'
#    3377 lines = cell.splitlines(keepends=True)
#    3378 for transform in self.input_transformers_post:
#
# ...

# %%
engine = sqlalchemy.create_engine(settings.DATABASES['default']['ENGINE'] + '://' + settings.DATABASES['default']['NAME'])
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 engine = sqlalchemy.create_engine(settings.DATABASES['default']['ENGINE'] + '://' + settings.DATABASES['default']['NAME'])
#
# File c:\Users\anush\Documents\My Life Documents\Fun\Coding\thetagang_site\.venv\Lib\site-packages\django\conf\__init__.py:81, in LazySettings.__getattr__(self, name)
#      79 """Return the value of a setting and cache it in self.__dict__."""
#      80 if (_wrapped := self._wrapped) is empty:
# ---> 81     self._setup(name)
#      82     _wrapped = self._wrapped
#      83 val = getattr(_wrapped, name)
#
# File c:\Users\anush\Documents\My Life Documents\Fun\Coding\thetagang_site\.venv\Lib\site-packages\django\conf\__init__.py:61, in LazySettings._setup(self, name)
#      59 if not settings_module:
#      60     desc = ("setting %s" % name) if name else "settings"
# ...
